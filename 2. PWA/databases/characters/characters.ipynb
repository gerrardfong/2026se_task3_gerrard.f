# %%
# %load_ext sql
# %sql sqlite:///characters.db

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS characters (
#     id          INTEGER PRIMARY KEY AUTOINCREMENT,
#     name        TEXT    NOT NULL,
#     species_id  INTEGER NOT NULL REFERENCES species(id),
#     profile_image TEXT DEFAULT "/static/icons/default_pfp.png",
#     user_id     INTEGER,
#     xp INTEGER DEFAULT 0
# );
#
# CREATE TABLE IF NOT EXISTS character_attributes (
#     character_id  INTEGER NOT NULL REFERENCES characters(id),
#     attribute     TEXT    NOT NULL REFERENCES attributes(attribute),
#     level         TEXT    NOT NULL REFERENCES rarities(level),
#     PRIMARY KEY (character_id, attribute)
# );
# Out:
#  * sqlite:///characters.db
# Done.
# Done.
# []

# %%
# %%sql
#
# -- Execution
#
# -- Add profile_image column to allow profile pictures
# -- UPDATE characters SET profile_image = '/static/icons/default_pfp.png' WHERE profile_image = "/static/icons/defaut_pfp.png";
#
# -- Add xp column to allow personalised xp
# -- ALTER TABLE characters ADD COLUMN xp INTEGER DEFAULT 0
#
# -- View results
# SELECT * FROM characters c JOIN character_attributes ca ON c.id = ca.character_id;
# Out:
#  * sqlite:///characters.db
# Done.
# []
