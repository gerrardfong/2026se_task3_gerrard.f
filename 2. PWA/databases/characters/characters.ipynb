# %%
# %load_ext sql
# %sql sqlite:///characters.db

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS characters (
#     id          INTEGER PRIMARY KEY AUTOINCREMENT,
#     name        TEXT    NOT NULL,
#     species_id  INTEGER NOT NULL REFERENCES species(id),
#     user_id     INTEGER
# );
#
# CREATE TABLE IF NOT EXISTS character_attributes (
#     character_id  INTEGER NOT NULL REFERENCES characters(id),
#     attribute     TEXT    NOT NULL REFERENCES attributes(attribute),
#     level         TEXT    NOT NULL REFERENCES rarities(level),
#     PRIMARY KEY (character_id, attribute)
# );
# UPDATE characters SET profile_image = '/static/icons/defaut_pfp.png' WHERE profile_image = "/static/default_profile.png";
# SELECT * FROM characters;
# Out:
#  * sqlite:///characters.db
# Done.
# Done.
# 9 rows affected.
# Done.
# [(1, 'ddler', 2, 2, '/static/icons/defaut_pfp.png'),
#  (2, 'michael', 4, 2, '/static/icons/defaut_pfp.png'),
#  (3, 'kelvinsnutsack', 5, 2, '/static/icons/defaut_pfp.png'),
#  (4, 'xabier', 1, 2, '/static/icons/defaut_pfp.png'),
#  (5, 'nah', 3, 2, '/static/icons/defaut_pfp.png'),
#  (6, 'yeah', 2, 2, '/static/icons/defaut_pfp.png'),
#  (7, 'Diddler89', 2, 2, '/static/icons/defaut_pfp.png'),
#  (8, 'niggl', 3, 2, '/static/icons/defaut_pfp.png'),
#  (9, 'toucher', 5, 2, '/static/icons/defaut_pfp.png')]
