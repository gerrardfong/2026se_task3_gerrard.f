# %%
# %load_ext sql
# %sql sqlite:///characters.db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS rarities (
#     level TEXT PRIMARY KEY,
#     rarity TEXT NOT NULL,
#     rank INTEGER,
#     threshold INTEGER NOT NULL DEFAULT 100
# );
#
# SELECT * FROM rarities;
# Out:
#  * sqlite:///characters.db
# Done.
# Done.
# []

# %%
# %%sql
# -- Further database execution
#
#
# -- Add ranks column to allow modifiers from species_buffs() to easily index through levels
# -- ALTER TABLE rarities ADD COLUMN rank INTEGER DEFAULT 0
#
# -- Add column threshold for xp thresholds that increase in difficulty as rank increases
# -- ALTER TABLE rarities ADD COLUMN threshold INTEGER NOT NULL DEFAULT 100
#
# INSERT OR IGNORE INTO rarities (level, rarity, rank, threshold) VALUES
#     ("Useless", "Legendary", 1, 100),
#     ("Subhuman", "Rare", 2, 200),
#     ("Chudlite", "Rare", 3, 300),
#     ("Average", "Common", 4, 400),
#     ("Athletic", "Common", 5, 500),
#     ("Building", "Uncommon", 6, 600),
#     ("City", "Rare", 7, 700),
#     ("Mountain", "Rare", 8, 800),
#     ("Island", "Epic", 9, 900),
#     ("Country", "Epic", 10, 1000),
#     ("Continental", "Epic", 11, 1100),
#     ("Planet", "Legendary", 12, 1200),
#     ("Star", "Legendary", 13, 1300),
#     ("Solar System", "Legendary", 14, 1400),
#     ("Galaxy", "Legendary", 15, 1500),
#     ("Universal", "Mythic", 16, 1600),
#     ("Multiversal", "Mythic", 17, 1700),
#     ("Outerversal", "Ultra", 18, 1800),
#     ("Absolute", "Ultra", 19, 1900);
#
# SELECT * FROM rarities;
# Out:
#  * sqlite:///characters.db
# 19 rows affected.
# Done.
# [('Useless', 'Legendary', 1, 100),
#  ('Subhuman', 'Rare', 2, 200),
#  ('Chudlite', 'Rare', 3, 300),
#  ('Average', 'Common', 4, 400),
#  ('Athletic', 'Common', 5, 500),
#  ('Building', 'Uncommon', 6, 600),
#  ('City', 'Rare', 7, 700),
#  ('Mountain', 'Rare', 8, 800),
#  ('Island', 'Epic', 9, 900),
#  ('Country', 'Epic', 10, 1000),
#  ('Continental', 'Epic', 11, 1100),
#  ('Planet', 'Legendary', 12, 1200),
#  ('Star', 'Legendary', 13, 1300),
#  ('Solar System', 'Legendary', 14, 1400),
#  ('Galaxy', 'Legendary', 15, 1500),
#  ('Universal', 'Mythic', 16, 1600),
#  ('Multiversal', 'Mythic', 17, 1700),
#  ('Outerversal', 'Ultra', 18, 1800),
#  ('Absolute', 'Ultra', 19, 1900)]
