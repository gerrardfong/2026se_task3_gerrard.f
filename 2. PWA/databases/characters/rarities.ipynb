# %%
# %load_ext sql
# %sql sqlite:///characters.db

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS rarities (
#     level TEXT PRIMARY KEY,
#     rarity TEXT NOT NULL,
#     rank INTEGER,
# );
#
# SELECT * FROM rarities;

# %%
# %%sql
#
# INSERT OR IGNORE INTO rarities (level, rarity) VALUES
#     ("Average", "Common"),
#     ("Athletic", "Common"),
#     ("Building", "Uncommon"),
#     ("Subhuman", "Rare"),
#     ("Chudlite", "Rare"),
#     ("City", "Rare"),
#     ("Mountain", "Rare"),
#     ("Island", "Epic"),
#     ("Country", "Epic"),
#     ("Continental", "Epic"),
#     ("Planet", "Legendary"),
#     ("Star", "Legendary"),
#     ("Solar System", "Legendary"),
#     ("Galaxy", "Legendary"),
#     ("Useless", "Legendary"),
#     ("Universal", "Mythic"),
#     ("Multiversal", "Mythic"),
#     ("Outerversal", "Ultra"),
#     ("Absolute", "Ultra");
#
# SELECT * FROM rarities;

# %%
# %%sql
#
# PRAGMA foreign_keys = OFF;
#
# DROP TABLE IF EXISTS rarities;
#
# CREATE TABLE rarities (
#     level TEXT PRIMARY KEY,
#     rarity TEXT NOT NULL,
#     rank INTEGER
# );
#
# INSERT INTO rarities (level, rarity, rank) VALUES
#     ('Useless', 'Legendary', 0),
#     ('Subhuman', 'Rare', 1),
#     ('Chudlite', 'Rare', 2),
#     ('Average', 'Common', 3),
#     ('Athletic', 'Common', 4),
#     ('Building', 'Uncommon', 5),
#     ('City', 'Rare', 6),
#     ('Mountain', 'Rare', 7),
#     ('Island', 'Epic', 8),
#     ('Country', 'Epic', 9),
#     ('Continental', 'Epic', 10),
#     ('Planet', 'Legendary', 11),
#     ('Star', 'Legendary', 12),
#     ('Solar System', 'Legendary', 13),
#     ('Galaxy', 'Legendary', 14),
#     ('Universal', 'Mythic', 15),
#     ('Multiversal', 'Mythic', 16),
#     ('Outerversal', 'Ultra', 17),
#     ('Absolute', 'Ultra', 18);
#
# PRAGMA foreign_keys = ON;
#
# SELECT * FROM rarities ORDER BY rank;
# Out:
#  * sqlite:///characters.db
# Done.
# Done.
# Done.
# 19 rows affected.
# Done.
# Done.
# [('Useless', 'Legendary', 0),
#  ('Subhuman', 'Rare', 1),
#  ('Chudlite', 'Rare', 2),
#  ('Average', 'Common', 3),
#  ('Athletic', 'Common', 4),
#  ('Building', 'Uncommon', 5),
#  ('City', 'Rare', 6),
#  ('Mountain', 'Rare', 7),
#  ('Island', 'Epic', 8),
#  ('Country', 'Epic', 9),
#  ('Continental', 'Epic', 10),
#  ('Planet', 'Legendary', 11),
#  ('Star', 'Legendary', 12),
#  ('Solar System', 'Legendary', 13),
#  ('Galaxy', 'Legendary', 14),
#  ('Universal', 'Mythic', 15),
#  ('Multiversal', 'Mythic', 16),
#  ('Outerversal', 'Ultra', 17),
#  ('Absolute', 'Ultra', 18)]

# %%
# %%sql
#
# ALTER TABLE rarities ADD COLUMN threshold INT DEFAULT 100;
#
# ALTER TABLE rarities ADD COLUMN rank INTEGER;
#
# UPDATE rarities SET rank = 0 WHERE level = 'Average';
# UPDATE rarities SET rank = 1 WHERE level = 'Athletic';
# UPDATE rarities SET rank = 2 WHERE level = 'Building';
# UPDATE rarities SET rank = 3 WHERE level = 'Subhuman';
# UPDATE rarities SET rank = 4 WHERE level = 'Chudlite';
# UPDATE rarities SET rank = 5 WHERE level = 'City';
# UPDATE rarities SET rank = 6 WHERE level = 'Mountain';
# UPDATE rarities SET rank = 7 WHERE level = 'Island';
# UPDATE rarities SET rank = 8 WHERE level = 'Country';
# UPDATE rarities SET rank = 9 WHERE level = 'Continental';
# UPDATE rarities SET rank = 10 WHERE level = 'Planet';
# UPDATE rarities SET rank = 11 WHERE level = 'Star';
# UPDATE rarities SET rank = 12 WHERE level = 'Solar System';
# UPDATE rarities SET rank = 13 WHERE level = 'Galaxy';
# UPDATE rarities SET rank = 14 WHERE level = 'Useless';
# UPDATE rarities SET rank = 15 WHERE level = 'Universal';
# UPDATE rarities SET rank = 16 WHERE level = 'Multiversal';
# UPDATE rarities SET rank = 17 WHERE level = 'Outerversal';
# UPDATE rarities SET rank = 18 WHERE level = 'Absolute';
