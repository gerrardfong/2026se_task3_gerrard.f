# %%
# %load_ext sql
# %sql sqlite:///characters.db

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS attributes(
#     attribute TEXT PRIMARY KEY
# );
# Out:
#  * sqlite:///characters.db
# Done.
# []

# %%
# %%sql
#
# INSERT OR IGNORE INTO attributes VALUES
#     (Strength),
#     (Durability),
#     (Stamina),
#     ();
#
# SELECT * FROM attributes
# Out:
#  * sqlite:///characters.db
# (sqlite3.OperationalError) table attributes has 1 columns but 2 values were supplied
# [SQL: INSERT OR IGNORE INTO attributes VALUES (
#     "Strength", "Water"
# );]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
